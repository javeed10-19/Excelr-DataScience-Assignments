# %% [markdown]
# ### python assignment-3: BASIC STATISTICS

# %% [raw]
# Descriptive Analytics and Data Preprocessing on Sales & Discounts Dataset
# Introduction
# ●	To perform descriptive analytics, visualize data distributions, and preprocess the dataset for further analysis.
# Descriptive Analytics for Numerical Columns
# ●	Objective: To compute and analyze basic statistical measures for numerical columns in the dataset.
# ●	Steps:
# 	Load the dataset into a data analysis tool or programming environment (e.g., Python with pandas library).
# 	Identify numerical columns in the dataset.
# 	Calculate the mean, median, mode, and standard deviation for these columns.
# 	Provide a brief interpretation of these statistics.
# Data Visualization
# ●	Objective: To visualize the distribution and relationship of numerical and categorical variables in the dataset.
# ●	Histograms:
# 	Plot histograms for each numerical column.
# 	Analyze the distribution (e.g., skewness, presence of outliers) and provide inferences.
# ●	Box Plots:
# 	Create boxplots for numerical variables to identify outliers and the interquartile range.
# 	Discuss any findings, such as extreme values or unusual distributions.
# ●	Bar Chart Analysis for Categorical Column:
# 	Identify categorical columns in the dataset.
# 	Create bar charts to visualize the frequency or count of each category.
# 	Analyze the distribution of categories and provide insights.
# Conclusion
# ●	Summarize the key findings from the descriptive analytics and data visualizations.

# %%
# import the python libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the given dataset
data = pd.read_csv(r"C:\Users\javee\Downloads\sales_data_with_discounts.csv")
data.head()
# Out:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102961
# 2      16100             112700           9.456886     10657.910157
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0    160346.501180
# 1     89323.897039
# 2    102042.089843
# 3    112235.925298
# 4     19927.053770

# %%
data.shape
# Out:
# (450, 13)

# %%
# information of the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    int64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    int64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 45.8+ KB

# %%
# checking missing values
data.isna().sum()
# Out:
# Date                 0
# Day                  0
# SKU                  0
# City                 0
# Volume               0
# BU                   0
# Brand                0
# Model                0
# Avg Price            0
# Total Sales Value    0
# Discount Rate (%)    0
# Discount Amount      0
# Net Sales Value      0
# dtype: int64

# %% [markdown]
# ### Identifying numerical columns

# %%
numerical_columns = data.select_dtypes(include=[np.number]).columns
numerical_columns
# Out:
# Index(['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
data.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495427     47847.912852
# ...

# %% [markdown]
# #### Volume

# %%
# Mean
data['Volume'].mean()
# Out:
# np.float64(5.066666666666666)

# %%
# Median
data['Volume'].median()
# Out:
# 4.0

# %%
# Mode
data['Volume'].mode()
# Out:
# 0    3
# Name: Volume, dtype: int64

# %%
# Standard Deviation
np.round(data['Volume'].std(),2)
# Out:
# np.float64(4.23)

# %% [markdown]
# #### AvgPrice

# %%
# mean
data['Avg Price'].mean()
# Out:
# np.float64(10453.433333333332)

# %%
# Median
data['Avg Price'].median()
# Out:
# 1450.0

# %%
# Mode
data['Avg Price'].mode()
# Out:
# 0     400
# 1     450
# 2     500
# 3    1300
# 4    8100
# Name: Avg Price, dtype: int64

# %%
# Standard Deviation
np.round(data['Avg Price'].std(),2)
# Out:
# np.float64(18079.9)

# %% [markdown]
# #### Total Sales Value

# %%
# Mean
data['Total Sales Value'].mean()
# Out:
# np.float64(33812.83555555555)

# %%
# Median
data['Total Sales Value'].median()
# Out:
# 5700.0

# %%
# Mode
data['Total Sales Value'].mode()
# Out:
# 0    24300
# Name: Total Sales Value, dtype: int64

# %%
# Standard Deviation
np.round(data['Total Sales Value'].std(),2)
# Out:
# np.float64(50535.07)

# %% [markdown]
# #### Discount Rate (%)

# %%
# Mean
data['Discount Rate (%)'].mean()
# Out:
# np.float64(15.155241895330914)

# %%
# Median
data['Discount Rate (%)'].median()
# Out:
# 16.57776564929597

# %%
# Standard deviation
np.round(data['Discount Rate (%)'].std(),2)
# Out:
# np.float64(4.22)

# %% [markdown]
# #### Discount Amount

# %%
# Mean
data['Discount Amount'].mean()
# Out:
# np.float64(3346.499424342415)

# %%
# Median 
data['Discount Amount'].median()
# Out:
# 988.9337332382784

# %%
# Standard deviation
np.round(data['Discount Amount'].std(),2)
# Out:
# np.float64(4509.9)

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# #### Histograms

# %%
plt.figure(figsize=(6,3))
sns.histplot(data["Volume"],kde=True,color='Blue', edgecolor='black')
plt.title("Histogram of Volume")
plt.show()

# %%
plt.figure(figsize=(6,3))
sns.histplot(data["Avg Price"],kde=True,color='Blue', edgecolor='black')
plt.title("Histogram of Avg Price")
plt.show()

# %%
plt.figure(figsize=(6,3))
sns.histplot(data['Total Sales Value'],kde=True,color='Blue',edgecolor='Black')
plt.title('Histogram of Total Sales Value')
plt.show()

# %%
plt.figure(figsize=(6,3))
sns.histplot(data['Discount Rate (%)'],kde=True,color='Blue',edgecolor='Black')
plt.title('Histogram of Discount Rate (%)')
plt.show()

# %%
plt.figure(figsize=(6,3))
sns.histplot(data['Discount Amount'], kde=True, color='Blue', edgecolor='Black')
plt.title('Histogram of Discount Amount')
plt.show()

# %%
plt.figure(figsize=(6,3))
sns.histplot(data['Net Sales Value'], kde=True, color='Blue', edgecolor='Black')
plt.title('Histogram of Net Sales Value')
plt.show()

# %% [markdown]
# #### BOXPLOTS

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data)
plt.title(' box plot')
plt.xticks(fontsize=7, rotation =45)
plt.show()

# %% [markdown]
# #### Identify outliers and the interquartile range.

# %%
Q1 = data['Total Sales Value'].quantile(0.25)
Q3 = data['Total Sales Value'].quantile(0.75)
IQR = Q3 - Q1

print(Q1,",", Q3)
print(IQR)
print("------------")
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

print(lower)
print(upper)

outliers = data[(data['Total Sales Value'] < lower) | 
                (data['Total Sales Value'] > upper)]

#print(outliers)
# Out:
# 2700.0 , 53200.0
# 50500.0
# ------------
# -73050.0
# 128950.0

# %%
outliers = pd.DataFrame(outliers)
outliers.head()
# Out:
#           Date       Day  SKU City  Volume       BU    Brand  Model  \
# 0   01-04-2021  Thursday  M01    C      15  Mobiles    RealU  RU-10
# 6   01-04-2021  Thursday  M07    C       3  Mobiles  Sumsang   S-20
# 9   01-04-2021  Thursday  M10    C       3  Mobiles   Orange   O-11
# 30  02-04-2021    Friday  M01    C      11  Mobiles    RealU  RU-10
# 36  02-04-2021    Friday  M07    C       3  Mobiles  Sumsang   S-20
#
#     Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0       12100             181500          11.654820     21153.498820
# 6       49100             147300           9.228812     13594.039719
# 9       60100             180300           9.928444     17900.983733
# 30      12100             133100          13.107140     17445.603828
# 36      49100             147300           5.252113      7736.361785
#
#     Net Sales Value
# 0     160346.501180
# 6     133705.960281
# 9     162399.016267
# 30    115654.396172
# 36    139563.638215

# %%
Q1 = data['Net Sales Value'].quantile(0.25)
Q3 = data['Net Sales Value'].quantile(0.75)
IQR = Q1 - Q3

print(Q1,',',Q3)
print(IQR)
print('----------------------------')
lower = Q1 - 1.5 * IQR
upper = Q3 - 1-5 * IQR

print(lower)
print(upper)

outliers = data[(data['Net Sales Value'] < lower) |
               (data['Net Sales Value'] > upper)]
#print(outliers)
# Out:
# 2202.2086453212287 , 47847.91285159138
# -45645.70420627015
# ----------------------------
# 70670.76495472644
# 276075.43388294213

# %%
Q1 = data['Avg Price'].quantile(0.25)
Q3 = data['Avg Price'].quantile(0.75)
IQR = Q1 -Q3

print(Q1,',',Q3)
print(IQR)
print('-----------------------------')
lower = Q1 - 1.5 * IQR
upper = Q3 - 1.5 * IQR

print(lower)
print(upper)

outliers = data[(data['Avg Price']<lower) |
                (data['Avg Price']>upper)]
#print(outliers)
# Out:
# 465.0 , 10100.0
# -9635.0
# -----------------------------
# 14917.5
# 24552.5

# %%
Q1 = data['Discount Amount'].quantile(0.25)
Q3 = data['Discount Amount'].quantile(0.75)
IQR = Q1 -Q3

print(Q1,',',Q3)
print(IQR)
print('-----------------------------')
lower = Q1 - 1.5 * IQR
upper = Q3 - 1.5 * IQR

print(lower)
print(upper)

outliers = data[(data['Discount Amount']<lower) |
                (data['Discount Amount']>upper)]
#print(outliers)
# Out:
# 460.4593038855329 , 5316.4954266866525
# -4856.03612280112
# -----------------------------
# 7744.513488087212
# 12600.54961088833

# %% [markdown]
# #### BAR CHART

# %%
plt.figure(figsize=(8,6))
sns.barplot(data,
           x='Brand',
           y='Volume',
           palette='vlag',
            hue='Brand'
)
plt.xticks(rotation=45, fontsize=8)
plt.title('Volume vs Brand')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(data,
           x='Model',
           y='Volume',
           palette='vlag',
           hue='Brand'
)
plt.title('Volume vs Model')
plt.xticks(rotation=45, fontsize=8)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(data,
           x='BU',
           y='Volume',
           palette='vlag',
           hue='Brand'
)
plt.xticks(rotation=45, fontsize=8)
plt.title('Volume vs BU')
plt.show()

# %% [markdown]
# #### Analyze the distribution of categories and provide insights.

# %% [raw]
# Overall Insights from Category Distribution:
#
# 1. Brand popularity – which mobile brand appears most in the dataset.
#
# 2. Market location – which city contributes most to sales.
#
# 3. Sales patterns – which days have higher transactions.
#
# 4.Product demand – which SKUs or models appear more frequently.
#
# --These insights help businesses understand product demand, market focus, and customer purchasing patterns .

# %% [markdown]
# #### Conclusion

# %% [raw]
# From the descriptive analysis and visualizations:
#
# 1. Numerical variables such as Volume, Price, and Sales Value provide insights into product demand and revenue.
#
# 2. Histograms reveal the distribution patterns and skewness of sales data.
#
# 3. Boxplots help detect outliers in price, sales, and discounts.
#
# 4. Bar charts show brand popularity and categorical distribution.
#
# 5. Data preprocessing ensures the dataset is clean and ready for further analysis such as predictive modeling or sales forecasting.
